# %%
import pandas as pd
import matplotlib.pyplot as p
from sklearn import linear_model

# %%
data=pd.read_csv('iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data['Species'].replace({'Iris-setosa':'1','Iris-versicolor':'2','Iris-virginica':'3'},inplace=True)

# %%
X=data[['Id','SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
Y=data[['Species']]

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0      1            5.1           3.5            1.4           0.2       1
# 1      2            4.9           3.0            1.4           0.2       1
# 2      3            4.7           3.2            1.3           0.2       1
# 3      4            4.6           3.1            1.5           0.2       1
# 4      5            5.0           3.6            1.4           0.2       1
# ..   ...            ...           ...            ...           ...     ...
# 145  146            6.7           3.0            5.2           2.3       3
# 146  147            6.3           2.5            5.0           1.9       3
# 147  148            6.5           3.0            5.2           2.0       3
# 148  149            6.2           3.4            5.4           2.3       3
# 149  150            5.9           3.0            5.1           1.8       3
#
# [150 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
reg=linear_model.LogisticRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# C:\Users\PMLS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\PMLS\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.predict(X_test)
# Out:
# array(['2', '1', '1', '2', '3', '2', '1', '1', '1', '2', '1', '3', '3',
#        '1', '2', '2', '3', '1', '1', '1', '2', '1', '3', '2', '1', '1',
#        '2', '2', '1', '3'], dtype=object)

# %%
X_test
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 78    79            6.0           2.9            4.5           1.5
# 4      5            5.0           3.6            1.4           0.2
# 22    23            4.6           3.6            1.0           0.2
# 85    86            6.0           3.4            4.5           1.6
# 141  142            6.9           3.1            5.1           2.3
# 93    94            5.0           2.3            3.3           1.0
# 20    21            5.4           3.4            1.7           0.2
# 19    20            5.1           3.8            1.5           0.3
# 23    24            5.1           3.3            1.7           0.5
# 67    68            5.8           2.7            4.1           1.0
# 30    31            4.8           3.1            1.6           0.2
# 125  126            7.2           3.2            6.0           1.8
# 149  150            5.9           3.0            5.1           1.8
# ...

# %%
len(X_test)
# Out:
# 30

# %%
len(X_train)
# Out:
# 120

# %%
reg.score(X_test,Y_test)
# Out:
# 1.0

# %%
import seaborn as sns

# %%
sns.pairplot(data[['Id','SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm','Species']],hue='Species')
# Out:
# C:\Users\PMLS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
